# %%
# Dependencies 
from pathlib import Path
import pandas as pd

# %%
# File paths
general_info = Path('Hospital_General_Information.csv')
locations = Path('hospital_locations.csv')

# %%
#Read in data
info_df = pd.read_csv(general_info)
info_df
# Out:
#       index  Provider ID                       Hospital Name  \
# 0         0        10005       MARSHALL MEDICAL CENTER SOUTH
# 1         1        10032                    WEDOWEE HOSPITAL
# 2         2        10131            CRESTWOOD MEDICAL CENTER
# 3         3        20001    PROVIDENCE ALASKA MEDICAL CENTER
# 4         4        20018  YUKON KUSKOKWIM DELTA REG HOSPITAL
# ...     ...          ...                                 ...
# 4813   4813       501333  KITTITAS VALLEY COMMUNITY HOSPITAL
# 4814   4814       450827         KELL WEST REGIONAL HOSPITAL
# 4815   4815       501310          NEWPORT COMMUNITY HOSPITAL
# 4816   4816       670107     BAYLOR EMERGENCY MEDICAL CENTER
# 4817   4817       450213            UNIVERSITY HEALTH SYSTEM
#
#                             Address           City State  ZIP Code  \
# 0        2505 U S HIGHWAY 431 NORTH           BOAZ    AL     35957
# 1             209 NORTH MAIN STREET        WEDOWEE    AL     36278
# ...

# %%
# List of columns
info_df.columns.values
# Out:
# array(['index', 'Provider ID', 'Hospital Name', 'Address', 'City',
#        'State', 'ZIP Code', 'County Name', 'Phone Number',
#        'Hospital Type', 'Hospital Ownership', 'Emergency Services',
#        'Meets criteria for meaningful use of EHRs',
#        'Hospital overall rating', 'Hospital overall rating footnote',
#        'Mortality national comparison',
#        'Mortality national comparison footnote',
#        'Safety of care national comparison',
#        'Safety of care national comparison footnote',
#        'Readmission national comparison',
#        'Readmission national comparison footnote',
#        'Patient experience national comparison',
#        'Patient experience national comparison footnote',
#        'Effectiveness of care national comparison',
#        'Effectiveness of care national comparison footnote',
#        'Timeliness of care national comparison',
#        'Timeliness of care national comparison footnote',
# ...

# %%
#Drop unnecessary columns 
info_df.drop(['index', 'Provider ID', 'Phone Number', 'Location', 'Meets criteria for meaningful use of EHRs', 'Mortality national comparison',
               'Mortality national comparison footnote', 'Safety of care national comparison',
              'Safety of care national comparison footnote', 'Readmission national comparison',
               'Readmission national comparison footnote', 'Patient experience national comparison',
              'Patient experience national comparison footnote','Effectiveness of care national comparison',
               'Effectiveness of care national comparison footnote','Timeliness of care national comparison',
               'Timeliness of care national comparison footnote', 'Efficient use of medical imaging national comparison',
               'Efficient use of medical imaging national comparison footnote','Hospital overall rating footnote'],inplace=True,axis=1)

info_df.head()
# Out:
#                         Hospital Name                     Address        City  \
# 0       MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH        BOAZ
# 1                    WEDOWEE HOSPITAL       209 NORTH MAIN STREET     WEDOWEE
# 2            CRESTWOOD MEDICAL CENTER          ONE HOSPITAL DR SE  HUNTSVILLE
# 3    PROVIDENCE ALASKA MEDICAL CENTER                  BOX 196604   ANCHORAGE
# 4  YUKON KUSKOKWIM DELTA REG HOSPITAL                  PO BOX 287      BETHEL
#
#   State  ZIP Code County Name         Hospital Type  \
# 0    AL     35957    MARSHALL  Acute Care Hospitals
# 1    AL     36278    RANDOLPH  Acute Care Hospitals
# 2    AL     35801     MADISON  Acute Care Hospitals
# 3    AK     99508   ANCHORAGE  Acute Care Hospitals
# 4    AK     99559      BETHEL  Acute Care Hospitals
#
#                             Hospital Ownership  Emergency Services  \
# 0  Government - Hospital District or Authority                True
# ...

# %%
# Identifying incomplete rows
info_df.count()
# Out:
# Hospital Name              4818
# Address                    4818
# City                       4818
# State                      4818
# ZIP Code                   4818
# County Name                4803
# Hospital Type              4818
# Hospital Ownership         4818
# Emergency Services         4818
# Hospital overall rating    3648
# dtype: int64

# %%
# Dropping all rows with missing information
info_df = info_df.dropna(how='any')

# %%
# Verified dropped rows
info_df.count()
# Out:
# Hospital Name              3644
# Address                    3644
# City                       3644
# State                      3644
# ZIP Code                   3644
# County Name                3644
# Hospital Type              3644
# Hospital Ownership         3644
# Emergency Services         3644
# Hospital overall rating    3644
# dtype: int64

# %%
# drop second info for rows with duplicate hospital name 
info_df = info_df.drop_duplicates(subset = "Hospital Name", keep = "first")
info_df
# Out:
#                              Hospital Name                     Address  \
# 0            MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH
# 1                         WEDOWEE HOSPITAL       209 NORTH MAIN STREET
# 2                 CRESTWOOD MEDICAL CENTER          ONE HOSPITAL DR SE
# 3         PROVIDENCE ALASKA MEDICAL CENTER                  BOX 196604
# 4       YUKON KUSKOKWIM DELTA REG HOSPITAL                  PO BOX 287
# ...                                    ...                         ...
# 4808  COLUMBIA ST MARYS HOSPITAL MILWAUKEE              2323 N LAKE DR
# 4811        AURORA LAKELAND MEDICAL CENTER        W3985 COUNTY ROAD NN
# 4813    KITTITAS VALLEY COMMUNITY HOSPITAL          603 SOUTH CHESTNUT
# 4814           KELL WEST REGIONAL HOSPITAL    5402 KELL WEST BOULEVARD
# 4817              UNIVERSITY HEALTH SYSTEM             4502 MEDICAL DR
#
#                City State  ZIP Code County Name              Hospital Type  \
# ...

# %%
# Save cleaned data as a csv file
info_df.to_csv('clean_info_df.csv',index=False,encoding = 'utf-8')

# %%
#Read in data
location_df = pd.read_csv(locations)
location_df.head()
# Out:
#    index             X             Y  OBJECTID        ID  \
# 0      0 -1.322651e+07  4.049626e+06         2  53391362
# 1      1 -1.315620e+07  4.031978e+06         3  11190023
# 2      2 -1.317190e+07  4.041752e+06         4  17090028
# 3      3 -1.313208e+07  4.037270e+06         5  23691706
# 4      4 -1.315222e+07  4.009980e+06         6  25190712
#
#                                                 NAME  \
# 0  LOS ROBLES HOSPITAL & MEDICAL CENTER - EAST CA...
# 1                  EAST LOS ANGELES DOCTORS HOSPITAL
# 2          SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD
# 3                      KINDRED HOSPITAL BALDWIN PARK
# 4                   LAKEWOOD REGIONAL MEDICAL CENTER
#
#                      ADDRESS             CITY STATE    ZIP  ...  \
# 0             150 VIA MERIDA  WESTLAKE VILAGE    CA  91362  ...
# 1    4060 WHITTIER BOULEVARD      LOS ANGELES    CA  90023  ...
# 2     6245 DE LONGPRE AVENUE        HOLLYWOOD    CA  90028  ...
# ...

# %%
# List of columns
location_df.columns.values
# Out:
# array(['index', 'X', 'Y', 'OBJECTID', 'ID', 'NAME', 'ADDRESS', 'CITY',
#        'STATE', 'ZIP', 'ZIP4', 'TELEPHONE', 'TYPE', 'STATUS',
#        'POPULATION', 'COUNTY', 'COUNTYFIPS', 'COUNTRY', 'LATITUDE',
#        'LONGITUDE', 'NAICS_CODE', 'NAICS_DESC', 'SOURCE', 'SOURCEDATE',
#        'VAL_METHOD', 'VAL_DATE', 'WEBSITE', 'STATE_ID', 'ALT_NAME',
#        'ST_FIPS', 'OWNER', 'TTL_STAFF', 'BEDS', 'TRAUMA', 'HELIPAD'],
#       dtype=object)

# %%
#Drop unnecessary columns 
location_df.drop(['index', 'X', 'Y', 'OBJECTID', 'ID', 'ZIP4','TELEPHONE','COUNTYFIPS', 'COUNTRY', 
    'NAICS_CODE', 'NAICS_DESC', 'SOURCE', 'SOURCEDATE',
       'VAL_METHOD', 'VAL_DATE', 'WEBSITE', 'STATE_ID', 'ALT_NAME',
       'ST_FIPS', 'TTL_STAFF', 'TRAUMA'],inplace=True,axis=1)

location_df.head()
# Out:
#                                                 NAME  \
# 0  LOS ROBLES HOSPITAL & MEDICAL CENTER - EAST CA...
# 1                  EAST LOS ANGELES DOCTORS HOSPITAL
# 2          SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD
# 3                      KINDRED HOSPITAL BALDWIN PARK
# 4                   LAKEWOOD REGIONAL MEDICAL CENTER
#
#                      ADDRESS             CITY STATE    ZIP  \
# 0             150 VIA MERIDA  WESTLAKE VILAGE    CA  91362
# 1    4060 WHITTIER BOULEVARD      LOS ANGELES    CA  90023
# 2     6245 DE LONGPRE AVENUE        HOLLYWOOD    CA  90028
# 3  14148 FRANCISQUITO AVENUE     BALDWIN PARK    CA  91706
# 4     3700 EAST SOUTH STREET         LAKEWOOD    CA  90712
#
#                  TYPE STATUS  POPULATION       COUNTY   LATITUDE   LONGITUDE  \
# 0  GENERAL ACUTE CARE   OPEN          40      VENTURA  34.154939 -118.815736
# 1  GENERAL ACUTE CARE   OPEN         127  LOS ANGELES  34.023647 -118.184165
# ...

# %%
# drop rows with dupliacted hospital name 
location_df = location_df.drop_duplicates(subset = "NAME", keep = "first")

# %%
# rename columns to lowercase 
location_df.rename(columns={'NAME': 'name', 'ADDRESS': 'address', 'CITY':'city', 'STATE':'state', 'ZIP':'zip', 'TYPE':'type', 'STATUS':'status',
       'POPULATION':'population', 'COUNTY':'county', 'LATITUDE':'latitude', 'LONGITUDE':'longitude', 'OWNER':'owner', 'BEDS':'beds',
       'HELIPAD':'helipad'})
# Out:
#                                                    name  \
# 0     LOS ROBLES HOSPITAL & MEDICAL CENTER - EAST CA...
# 1                     EAST LOS ANGELES DOCTORS HOSPITAL
# 2             SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD
# 3                         KINDRED HOSPITAL BALDWIN PARK
# 4                      LAKEWOOD REGIONAL MEDICAL CENTER
# ...                                                 ...
# 7616                  OCHSNER MEDICAL COMPLEX IBERVILLE
# 7617                        PAM REHAB HOSPITAL OF DOVER
# 7618                        SUN BEHAVIORAL DELAWARE LLC
# 7619  TEXAS HEALTH NEIGHBORHOOD CARE & WELLNESS WILL...
# 7622                   WOODWARD STATE HOSPITAL & SCHOOL
#
#                         address             city state    zip  \
# 0                150 VIA MERIDA  WESTLAKE VILAGE    CA  91362
# 1       4060 WHITTIER BOULEVARD      LOS ANGELES    CA  90023
# 2        6245 DE LONGPRE AVENUE        HOLLYWOOD    CA  90028
# ...

# %%
# Save cleaned data as a csv file
location_df.to_csv('clean_location_df.csv',index=False,encoding = 'utf-8')

# %%
location_df.columns
# Out:
# Index(['NAME', 'ADDRESS', 'CITY', 'STATE', 'ZIP', 'TYPE', 'STATUS',
#        'POPULATION', 'COUNTY', 'LATITUDE', 'LONGITUDE', 'OWNER', 'BEDS',
#        'HELIPAD'],
#       dtype='object')
